# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/insurance_claims.csv')

# %%
df.head()
# Out:
#    months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                 328   48         521585       2014-10-17           OH
# 1                 228   42         342868       2006-06-27           IN
# 2                 134   29         687698       2000-09-06           OH
# 3                 256   41         227811       1990-05-25           IL
# 4                 228   44         367455       2014-06-06           IL
#
#   policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 0    250/500               1000                1406.91               0
# 1    250/500               2000                1197.22         5000000
# 2    100/300               2000                1413.14         5000000
# 3    250/500               2000                1415.74         6000000
# 4   500/1000               1000                1583.91         6000000
#
#    insured_zip  ... police_report_available total_claim_amount injury_claim  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 40 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1000 non-null   int64
#  1   age                          1000 non-null   int64
#  2   policy_number                1000 non-null   int64
#  3   policy_bind_date             1000 non-null   object
#  4   policy_state                 1000 non-null   object
#  5   policy_csl                   1000 non-null   object
#  6   policy_deductable            1000 non-null   int64
#  7   policy_annual_premium        1000 non-null   float64
#  8   umbrella_limit               1000 non-null   int64
#  9   insured_zip                  1000 non-null   int64
#  10  insured_sex                  1000 non-null   object
#  11  insured_education_level      1000 non-null   object
#  12  insured_occupation           1000 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# months_as_customer                0
# age                               0
# policy_number                     0
# policy_bind_date                  0
# policy_state                      0
# policy_csl                        0
# policy_deductable                 0
# policy_annual_premium             0
# umbrella_limit                    0
# insured_zip                       0
# insured_sex                       0
# insured_education_level           0
# insured_occupation                0
# insured_hobbies                   0
# insured_relationship              0
# capital-gains                     0
# capital-loss                      0
# incident_date                     0
# incident_type                     0
# collision_type                    0
# incident_severity                 0
# authorities_contacted            91
# incident_state                    0
# incident_city                     0
# incident_location                 0
# incident_hour_of_the_day          0
# ...

# %%
df.tail()
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 995                   3   38         941851       1991-07-16           OH
# 996                 285   41         186934       2014-01-05           IL
# 997                 130   34         918516       2003-02-17           OH
# 998                 458   62         533940       2011-11-18           IL
# 999                 456   60         556080       1996-11-11           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# 995   500/1000               1000                1310.80               0
# 996    100/300               1000                1436.79               0
# 997    250/500                500                1383.49         3000000
# 998   500/1000               2000                1356.92         5000000
# 999    250/500               1000                 766.19               0
#
#      insured_zip  ... police_report_available total_claim_amount injury_claim  \
# ...

# %%
df.shape
# Out:
# (1000, 40)

# %%
df.replace("?",np.nan,inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 40 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1000 non-null   int64
#  1   age                          1000 non-null   int64
#  2   policy_number                1000 non-null   int64
#  3   policy_bind_date             1000 non-null   object
#  4   policy_state                 1000 non-null   object
#  5   policy_csl                   1000 non-null   object
#  6   policy_deductable            1000 non-null   int64
#  7   policy_annual_premium        1000 non-null   float64
#  8   umbrella_limit               1000 non-null   int64
#  9   insured_zip                  1000 non-null   int64
#  10  insured_sex                  1000 non-null   object
#  11  insured_education_level      1000 non-null   object
#  12  insured_occupation           1000 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# months_as_customer                0
# age                               0
# policy_number                     0
# policy_bind_date                  0
# policy_state                      0
# policy_csl                        0
# policy_deductable                 0
# policy_annual_premium             0
# umbrella_limit                    0
# insured_zip                       0
# insured_sex                       0
# insured_education_level           0
# insured_occupation                0
# insured_hobbies                   0
# insured_relationship              0
# capital-gains                     0
# capital-loss                      0
# incident_date                     0
# incident_type                     0
# collision_type                  178
# incident_severity                 0
# authorities_contacted            91
# incident_state                    0
# incident_city                     0
# incident_location                 0
# incident_hour_of_the_day          0
# ...

# %%
df= df.drop("_c39", axis =1)

# %%
df1= df.copy()

# %%
import missingno as msno
msno.bar(df)
# Out:
# <Axes: >

# %%
df1.dropna(inplace= True)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 340 entries, 0 to 992
# Data columns (total 39 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           340 non-null    int64
#  1   age                          340 non-null    int64
#  2   policy_number                340 non-null    int64
#  3   policy_bind_date             340 non-null    object
#  4   policy_state                 340 non-null    object
#  5   policy_csl                   340 non-null    object
#  6   policy_deductable            340 non-null    int64
#  7   policy_annual_premium        340 non-null    float64
#  8   umbrella_limit               340 non-null    int64
#  9   insured_zip                  340 non-null    int64
#  10  insured_sex                  340 non-null    object
#  11  insured_education_level      340 non-null    object
#  12  insured_occupation           340 non-null    object
# ...

# %%
df2 = df.copy()

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 39 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1000 non-null   int64
#  1   age                          1000 non-null   int64
#  2   policy_number                1000 non-null   int64
#  3   policy_bind_date             1000 non-null   object
#  4   policy_state                 1000 non-null   object
#  5   policy_csl                   1000 non-null   object
#  6   policy_deductable            1000 non-null   int64
#  7   policy_annual_premium        1000 non-null   float64
#  8   umbrella_limit               1000 non-null   int64
#  9   insured_zip                  1000 non-null   int64
#  10  insured_sex                  1000 non-null   object
#  11  insured_education_level      1000 non-null   object
#  12  insured_occupation           1000 non-null   object
# ...

# %%
df2['collision_type'] = df2['collision_type'].fillna(df2['collision_type'].mode()[0])

# %%
df2['collision_type']
# Out:
# 0       Side Collision
# 1       Rear Collision
# 2       Rear Collision
# 3      Front Collision
# 4       Rear Collision
#             ...
# 995    Front Collision
# 996     Rear Collision
# 997     Side Collision
# 998     Rear Collision
# 999     Rear Collision
# Name: collision_type, Length: 1000, dtype: object

# %%
df2['property_damage'] = df2['property_damage'].fillna(df2['property_damage'].mode()[0])

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 39 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1000 non-null   int64
#  1   age                          1000 non-null   int64
#  2   policy_number                1000 non-null   int64
#  3   policy_bind_date             1000 non-null   object
#  4   policy_state                 1000 non-null   object
#  5   policy_csl                   1000 non-null   object
#  6   policy_deductable            1000 non-null   int64
#  7   policy_annual_premium        1000 non-null   float64
#  8   umbrella_limit               1000 non-null   int64
#  9   insured_zip                  1000 non-null   int64
#  10  insured_sex                  1000 non-null   object
#  11  insured_education_level      1000 non-null   object
#  12  insured_occupation           1000 non-null   object
# ...

# %%
df1.iloc[:, 2:7]
# Out:
#      policy_number policy_bind_date policy_state policy_csl  policy_deductable
# 0           521585       2014-10-17           OH    250/500               1000
# 2           687698       2000-09-06           OH    100/300               2000
# 5           104594       2006-10-12           OH    250/500               1000
# 8           485665       1997-02-05           IL    100/300                500
# 11          214618       1999-05-29           OH    100/300               2000
# ..             ...              ...          ...        ...                ...
# 980         908935       2009-12-11           IL   500/1000               1000
# 984         974522       2000-01-27           IN    250/500               1000
# 988         591269       1999-01-09           IN    100/300                500
# 991         109392       2006-07-12           OH    100/300               1000
# 992         215278       2007-10-24           IN    100/300                500
#
# [340 rows x 5 columns]

# %%
df1.iloc[:,-1]
# Out:
# 0      Y
# 2      N
# 5      Y
# 8      N
# 11     N
#       ..
# 980    N
# 984    N
# 988    N
# 991    N
# 992    N
# Name: fraud_reported, Length: 340, dtype: object

# %%
df1.iloc[20:400,0]
# Out:
# 47     355
# 55      22
# 58      11
# 59     151
# 61     245
#       ...
# 980    245
# 984    163
# 988    295
# 991    257
# 992     94
# Name: months_as_customer, Length: 320, dtype: int64

# %%
df1.iloc[:,:-1]
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                   328   48         521585       2014-10-17           OH
# 2                   134   29         687698       2000-09-06           OH
# 5                   256   39         104594       2006-10-12           OH
# 8                    27   33         485665       1997-02-05           IL
# 11                  447   61         214618       1999-05-29           OH
# ..                  ...  ...            ...              ...          ...
# 980                 245   40         908935       2009-12-11           IL
# 984                 163   36         974522       2000-01-27           IN
# 988                 295   46         591269       1999-01-09           IN
# 991                 257   44         109392       2006-07-12           OH
# 992                  94   26         215278       2007-10-24           IN
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 39 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1000 non-null   int64
#  1   age                          1000 non-null   int64
#  2   policy_number                1000 non-null   int64
#  3   policy_bind_date             1000 non-null   object
#  4   policy_state                 1000 non-null   object
#  5   policy_csl                   1000 non-null   object
#  6   policy_deductable            1000 non-null   int64
#  7   policy_annual_premium        1000 non-null   float64
#  8   umbrella_limit               1000 non-null   int64
#  9   insured_zip                  1000 non-null   int64
#  10  insured_sex                  1000 non-null   object
#  11  insured_education_level      1000 non-null   object
#  12  insured_occupation           1000 non-null   object
# ...

# %%
df3 = df.copy()

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 39 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1000 non-null   int64
#  1   age                          1000 non-null   int64
#  2   policy_number                1000 non-null   int64
#  3   policy_bind_date             1000 non-null   object
#  4   policy_state                 1000 non-null   object
#  5   policy_csl                   1000 non-null   object
#  6   policy_deductable            1000 non-null   int64
#  7   policy_annual_premium        1000 non-null   float64
#  8   umbrella_limit               1000 non-null   int64
#  9   insured_zip                  1000 non-null   int64
#  10  insured_sex                  1000 non-null   object
#  11  insured_education_level      1000 non-null   object
#  12  insured_occupation           1000 non-null   object
# ...

# %%
ds = pd.read_csv('/content/Data (2).csv')

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values=np.nan, strategy='mean')
imputer.fit(ds.iloc[:,1:3])
ds.iloc[:,1:3] = imputer.transform(ds.iloc[:,1:3])

# %%
ds.iloc[:,1:3]
# Out:
#          Age        Salary
# 0  44.000000  72000.000000
# 1  27.000000  48000.000000
# 2  30.000000  54000.000000
# 3  38.000000  61000.000000
# 4  40.000000  63777.777778
# 5  35.000000  58000.000000
# 6  38.777778  52000.000000
# 7  48.000000  79000.000000
# 8  50.000000  83000.000000
# 9  37.000000  67000.000000

# %%
from sklearn.impute import SimpleImputer
inmputer = SimpleImputer(missing_values=np.nan, strategy='mean')
ds.iloc[:,1:3] = imputer.fit_transform(ds.iloc[:,1:3])

# %%
ds.iloc[:,1:3]
# Out:
#          Age        Salary
# 0  44.000000  72000.000000
# 1  27.000000  48000.000000
# 2  30.000000  54000.000000
# 3  38.000000  61000.000000
# 4  40.000000  63777.777778
# 5  35.000000  58000.000000
# 6  38.777778  52000.000000
# 7  48.000000  79000.000000
# 8  50.000000  83000.000000
# 9  37.000000  67000.000000

# %%
import seaborn as sns
sns.boxplot(df['months_as_customer'])
# Out:
# <Axes: ylabel='months_as_customer'>

# %%
sns.boxplot(df['vehicle_claim'])
# Out:
# <Axes: ylabel='vehicle_claim'>

# %%
sns.boxplot(df['property_claim'])
# Out:
# <Axes: ylabel='property_claim'>

# %%
import matplotlib.pyplot as plt


plt.figure(figsize =(20,15))
plotnumber = 1

for i in df.columns:
  if plotnumber <= 24:
    ax = plt.subplot(5,5,plotnumber)
    sns.boxplot(df[i])
  plotnumber += 1

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize = (20,15))
plotnumber  = 1

for i in df.columns:
  if plotnumber <=24:
    ax = plt.subplot(5,5,plotnumber)
    sns.histplot(df[i])
  plotnumber += 1

plt.tight_layout()
plt.show()

# %%
df['policy_number'].plot(kind = 'box')
plt.show()

# %%
ds1 = ds.copy()

# %%
from sklearn.preprocessing import LabelEncoder
dx = LabelEncoder()
ds['Country'] = dx.fit_transform(ds['Country'])
ds['Purchased'] = dx.fit_transform(ds['Purchased'])
ds
# Out:
#    Country        Age        Salary  Purchased
# 0        0  44.000000  72000.000000          0
# 1        2  27.000000  48000.000000          1
# 2        1  30.000000  54000.000000          0
# 3        2  38.000000  61000.000000          0
# 4        1  40.000000  63777.777778          1
# 5        0  35.000000  58000.000000          1
# 6        2  38.777778  52000.000000          0
# 7        0  48.000000  79000.000000          1
# 8        1  50.000000  83000.000000          0
# 9        0  37.000000  67000.000000          1

# %%
plt.figure(figsize=(20,15))

corr = ds.corr()

sns.heatmap(data = corr,annot = True, fmt='.2g',linewidth = 1)
plt.show()

# %%
lbl = LabelEncoder()
for i in ds1:
  ds1[i] = ds1[[i]].apply(lbl.fit_transform)

# %%
ds1
# Out:
#    Country  Age  Salary  Purchased
# 0        0    7       7          0
# 1        2    0       0          1
# 2        1    1       2          0
# 3        2    4       4          0
# 4        1    6       5          1
# 5        0    2       3          1
# 6        2    5       1          0
# 7        0    8       8          1
# 8        1    9       9          0
# 9        0    3       6          1
